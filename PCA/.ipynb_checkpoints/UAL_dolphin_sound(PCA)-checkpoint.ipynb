# %%
import soundfile as sf
import scipy.signal
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import random

# %%
data, fs = sf.read("dolphinsound.wav")
ch1 = data[:,0]
ch1.shape
# Out:
# (40320000,)

# %%
f,t,z = scipy.signal.stft(ch1, fs=fs, window='hann', nperseg=1024, 
                      noverlap=int(1024*.9), nfft=None, boundary=None,
                      padded=False
)

# %%
w = scipy.signal.get_window('hann', 1024, fftbins=True)

# %%
s = ch1[:1024]

# %%
X = scipy.fft.fft(s*w)*2/1024

# %%
np.sum(X[:513] - z[:,0])
# Out:
# 0j

# %%
df = pd.read_csv("whistle_time.csv", sep=r'\s*,\s*')
# Out:
# /home/yong/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
time_shift = 103
process = np.zeros(515).reshape(515,1)
for index, data in df.iterrows():
    random.seed(index)
    start = int(math.ceil((data["start"]-t[0])/time_shift*96000))
    end = int(math.floor((data["end"]-t[0])/time_shift*96000))
    choose = random.sample(range(start, end+1), k=20)
    
    X = z[:,choose]
    X = abs(X)
    target = (np.ones(20)*data["target"]).reshape(1,20)
    i = (np.ones(20)*index).reshape(1,20)
    X = np.concatenate((X, target, i), axis=0)
    process = np.concatenate((process, X), axis=1)
process.shape
# Out:
# (515, 1201)

# %% [markdown]
# Important change!!!!!
# integrate the frequency energy(0.1 sec)

# %%
time_shift = 103
process = np.zeros(515).reshape(515,1)
for index, data in df.iterrows():
    random.seed(index)
    X = np.zeros(513).reshape(513,1)
    start = int(math.ceil((data["start"]-t[0])/time_shift*96000))
    end = int(math.floor((data["end"]-t[0])/time_shift*96000))
    choose = random.sample(range(start, end+1), k=20)
    for jj in choose:
        amp = np.zeros(513).reshape(513,1)
        for jjj in range(100):
            amp += abs(z[:,jj+jjj]).reshape(513,1)
        X = np.concatenate((X,amp), axis=1)    
    X = np.delete(X,0,axis=1)
    target = (np.ones(20)*data["target"]).reshape(1,20)
    i = (np.ones(20)*index).reshape(1,20)
    X = np.concatenate((X, target, i), axis=0)
    process = np.concatenate((process, X), axis=1)
process.shape

# %%
n = np.delete(process.T, 0, axis=0)
col = ["feature {}".format(i) for i in range(1,514)]
col.append("target")
col.append("id(in whistle_time.csv file)")
df_create = pd.DataFrame(n, columns=col)
df_create.head()
# Out:
#    feature 1  feature 2  feature 3  feature 4  feature 5  feature 6  \
# 0   0.146020   0.086985   0.043168   0.029374   0.023790   0.027549
# 1   0.123968   0.076024   0.040347   0.033741   0.026560   0.030807
# 2   0.087833   0.065238   0.036393   0.039288   0.030928   0.029106
# 3   0.115863   0.074549   0.047799   0.076833   0.062385   0.043793
# 4   0.168201   0.093635   0.036123   0.043355   0.045087   0.034992
#
#    feature 7  feature 8  feature 9  feature 10  ...  feature 506  feature 507  \
# 0   0.032863   0.038155   0.043601    0.037522  ...     0.003140     0.002608
# 1   0.035344   0.036740   0.041879    0.039488  ...     0.003189     0.003006
# 2   0.033749   0.039056   0.051817    0.055816  ...     0.003283     0.003163
# 3   0.055729   0.045799   0.043081    0.054879  ...     0.003049     0.003070
# 4   0.039980   0.042710   0.057557    0.047108  ...     0.003093     0.003142
#
#    feature 508  feature 509  feature 510  feature 511  feature 512  \
# 0     0.002962     0.003287     0.003116     0.002838     0.002907
# 1     0.003220     0.003316     0.003214     0.002981     0.003089
# 2     0.002682     0.002722     0.002776     0.002637     0.002089
# 3     0.003310     0.003372     0.003162     0.002483     0.002399
# 4     0.003416     0.003217     0.003114     0.002832     0.002667
#
#    feature 513  target  id(in whistle_time.csv file)
# 0     0.002618     1.0                           0.0
# 1     0.002930     1.0                           0.0
# 2     0.001586     1.0                           0.0
# 3     0.002372     1.0                           0.0
# 4     0.002394     1.0                           0.0
#
# [5 rows x 515 columns]

# %%
df_create.to_pickle("dol_feature_2")

# %%
df1 = pd.read_pickle("dol_feature")
df1.head()
# Out:
#    feature 1  feature 2  feature 3  feature 4  feature 5  feature 6  \
# 0   0.002335   0.001528   0.000376   0.000277   0.000266   0.000333
# 1   0.001655   0.000828   0.000371   0.000259   0.000084   0.000225
# 2   0.000401   0.000588   0.000240   0.000400   0.000231   0.000103
# 3   0.000997   0.000663   0.000363   0.001196   0.000887   0.000140
# 4   0.001638   0.001067   0.000291   0.000091   0.000134   0.000125
#
#    feature 7  feature 8  feature 9  feature 10  ...  feature 506  feature 507  \
# 0   0.000568   0.000363   0.000654    0.000657  ...     0.000019     0.000011
# 1   0.000252   0.000195   0.000338    0.000440  ...     0.000033     0.000051
# 2   0.000306   0.000377   0.000214    0.000234  ...     0.000031     0.000016
# 3   0.000559   0.000732   0.000419    0.001036  ...     0.000046     0.000031
# 4   0.000531   0.000638   0.000332    0.000423  ...     0.000027     0.000009
#
#    feature 508  feature 509  feature 510  feature 511  feature 512  \
# 0     0.000008     0.000032     0.000043     0.000034     0.000034
# 1     0.000040     0.000053     0.000039     0.000018     0.000032
# 2     0.000016     0.000022     0.000011     0.000013     0.000012
# 3     0.000026     0.000053     0.000036     0.000009     0.000013
# 4     0.000035     0.000022     0.000022     0.000020     0.000058
#
#    feature 513  target  id(in whistle_time.csv file)
# 0     0.000035     1.0                           0.0
# 1     0.000053     1.0                           0.0
# 2     0.000004     1.0                           0.0
# 3     0.000024     1.0                           0.0
# 4     0.000036     1.0                           0.0
#
# [5 rows x 515 columns]
